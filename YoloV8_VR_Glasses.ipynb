# %% [markdown]
# # **YOLOv8 – VR Glasses Detector**

# %% [markdown]
# ## **0. Connect Github**

# %% [markdown]
# **Initialize Github**

# %%
import getpass
USERNAME = "DennisR96"
EMAIL = "dennisraek@gmail.com"
TOKEN = getpass.getpass("INSERT TOKEN: ")
REPOSITORY = "BA_DET"

# !git clone https://$USERNAME:$TOKEN@github.com/$USERNAME/$REPOSITORY
# !git config --global user.email $EMAIL
# !git config --global user.name $USERNAME

# %cd $REPOSITORY
# Out:
# INSERT TOKEN: ··········
# Cloning into 'BA_DET'...
# ...
# /content/BA_DET

# %% [markdown]
# **Push Github**

# %%
# !gdown 1TVLVpV6xRgQwQnkjQWS7EECYhJvhw28H
# !git add --all
# !git commit -m "finished building"
# !git push -u origin main
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TVLVpV6xRgQwQnkjQWS7EECYhJvhw28H
# To: /content/BA_DET/YoloV8_VR_Glasses.ipynb
# 100% 438k/438k [00:00<00:00, 24.5MB/s]
# [main c88c7dd] finished building
#  1 file changed, 1 insertion(+)
#  create mode 100644 YoloV8_VR_Glasses.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 283.33 KiB | 10.12 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/DennisR96/BA_DET
#    4b4056a..c88c7dd  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %% [markdown]
# **Write .gitignore**

# %%
# %%writefile .gitignore
# *.jpg
#
# dataset/
# runs/
# Out:
# Overwriting .gitignore

# %% [markdown]
# # **1. Requirements**

# %% [markdown]
# **Install Requirements.txt**

# %%
# !pip install -q -r "requirements.txt"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 42.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 74.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00

# %% [markdown]
# **Download Dataset**

# %%
# !mkdir dataset
# !gdown 1k3TFnEmhMZwUifYxQIhQ42hZP7dYhw3d -O dataset/VR_Glasses.zip
# !unzip -qq dataset/VR_Glasses.zip -d dataset/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1k3TFnEmhMZwUifYxQIhQ42hZP7dYhw3d
# To: /content/BA_DET/dataset/VR_Glasses.zip
# 100% 5.45M/5.45M [00:00<00:00, 170MB/s]

# %% [markdown]
# **Download Model**

# %%
# !gdown 1fYTMlY2CbTGDBxA7MlQuKnVDdIWVlf24 -O model/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fYTMlY2CbTGDBxA7MlQuKnVDdIWVlf24
# To: /content/BA_DET/model/YOLOv8_VR_Glasses.pt
# 100% 6.25M/6.25M [00:00<00:00, 182MB/s]

# %% [markdown]
# **Imports**

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import os
import streamlit as st

# %% [markdown]
# ## **2. Model**

# %%
model = YOLO('model/YOLOv8_VR_Glasses.pt')

# %% [markdown]
# ## **3. Experiment**

# %% [markdown]
# ### **3.1 Train**

# %%
model.train(
    data='dataset/data.yaml',
    epochs=100,
    imgsz=640)
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Export

# %%
model.export()
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.30GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.0.1+cu118...
# TorchScript: export success ✅ 2.3s, saved as 'runs/detect/train/weights/best.torchscript' (11.9 MB)
#
# Export complete (4.1s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.torchscript imgsz=640 data=/content/dataset/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train/weights/best.torchscript'

# %% [markdown]
# ### **3.2 Inference**

# %%
url = "https://images.fineartamerica.com/images/artworkimages/mediumlarge/2/2-man-enjoying-vr-headset-michal-bednarek.jpg"

result = model(
    source = url,
    save=True)

filename = os.path.basename(result[0].path)
dir = "runs/detect/predict"
filedir = os.path.join(dir,filename)

Image.open(filedir)
# Out:
# ...
# 100%|██████████| 99.3k/99.3k [00:00<00:00, 2.29MB/s]
# image 1/1 /content/BA_DET/2-man-enjoying-vr-headset-michal-bednarek.jpg: 448x640 1 VR Glasses, 231.9ms
# Speed: 4.6ms preprocess, 231.9ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600>

# %% [markdown]
# ### **3.3 - Streamlit App**

# %%
# %%writefile app.py
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import os
import streamlit as st
import numpy as np

model = YOLO('model/YOLOv8_VR_Glasses.pt')
title = st.text_input('Insert Image Link')

if title:
  result = model(
    source = title,
    save=False)

  for r in result:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image

  st.image(im)
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] \ fetchMetadata: sill resolveWithNewModule yargs@17.1.1 ch
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.231.130.28:8501
#
# npx: installed 22 in 2.476s
# your url is: https://ten-ads-listen.loca.lt
#
# ...
# 100% 88.6k/88.6k [00:00<00:00, 424kB/s]
# image 1/1 /content/BA_DET/imago80014169h-jpg-100-1280x720.jpg: 384x640 1 VR Glasses, 389.9ms
# Speed: 13.2ms preprocess, 389.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#   Stopping...
# ^C
